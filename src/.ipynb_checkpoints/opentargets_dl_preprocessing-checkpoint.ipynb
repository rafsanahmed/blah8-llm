# %%
import json
import os
import numpy as np
import pandas as pd

# %% [markdown]
# # Target

# %%
folder_ = "../data/ot/targets/"
infile = folder_+"part-00000-263f3ae4-3f0d-4298-9ec5-d7c84b7d0d26-c000.json"

# %%
def read_json(infile):
    with open(infile, encoding="utf8") as f:
        doc = json.loads(f.read())
    return doc

# %%
read_json(infile)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 read_json(infile)
#
# Cell In[6], line 3, in read_json(infile)
#       1 def read_json(infile):
#       2     with open(infile, encoding="utf8") as f:
# ----> 3         doc = json.loads(f.read())
#       4     return doc
#
# File ~\anaconda3\envs\weave\lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# ...

# %%
columns = ["id", "approvedSymbol", "functionDescriptions","synonyms", "nameSynonyms", "subcellularLocations", "targetClass", "pathways", "homologues", "homologyClass", "tractability"]
targets_lol = [] # targets list of lists

with open(infile, encoding="utf8") as f:
    for line in f.readlines()[:10]:
        ent = json.loads(line)
        l = []
        for c in columns:
            
            if c in ent:
                if c in ["synonyms", "nameSynonyms", "targetClass"] and len(ent[c])>0:
                    l.append("\t".join([item["label"] for item in ent[c]]))
                elif c == "subcellularLocations" and len(ent[c])>0:
                    l.append("\t".join([item["location"] for item in ent[c]]))
                else:
                    l.append(ent[c])
            else:
                l.append("")
        targets_lol.append(l)
                
df_targets = pd.DataFrame(targets_lol, columns=columns)
df_targets
# Out:
#                 id approvedSymbol  \
# 0  ENSG00000020219        CCT8L1P
# 1  ENSG00000059588         TARBP1
# 2  ENSG00000070182           SPTB
# 3  ENSG00000070366           SMG6
# 4  ENSG00000072071         ADGRL1
# 5  ENSG00000073536           NLE1
# 6  ENSG00000075290          WNT8B
# 7  ENSG00000083454          P2RX5
# 8  ENSG00000083782           EPYC
# 9  ENSG00000086200          IPO11
#
#                                 functionDescriptions  \
# 0  [Possible molecular chaperone; assists the fol...
# 1  [Probable S-adenosyl-L-methionine-dependent me...
# 2  [Spectrin is the major constituent of the cyto...
# 3  [Component of the telomerase ribonucleoprotein...
# 4  [Calcium-independent receptor of high affinity...
# 5  [Plays a role in regulating Notch activity. Pl...
# 6  [Ligand for members of the frizzled family of ...
# 7  [Receptor for ATP that acts as a ligand-gated ...
# 8  [May have a role in bone formation and also in...
# ...

# %%
[print (x) for x in df_targets.functionDescriptions[0:10]]
# Out:
# ['Possible molecular chaperone; assists the folding of proteins upon ATP hydrolysis. .']
# ['Probable S-adenosyl-L-methionine-dependent methyltransferase which methylates RNA molecules such as tRNAs. .', '(Microbial infection) In case of infection by HIV-1, it binds to the loop region of TAR RNA, a region also bound by RNA polymerase II (PubMed:7638159, PubMed:8626763, PubMed:8846792). Binding of TARBP1 and RNA polymerase II to HIV-1 TAR RNA is mutually exclusive, suggesting that TARBP1 may function alone or in conjunction with HIV-1 Tat to disengage RNA polymerase II from HIV-1 TAR RNA (PubMed:7638159, PubMed:8626763, PubMed:8846792). {ECO:0000269|PubMed:7638159, ECO:0000269|PubMed:8626763, ECO:0000269|PubMed:8846792}.']
# ['Spectrin is the major constituent of the cytoskeletal network underlying the erythrocyte plasma membrane. It associates with band 4.1 and actin to form the cytoskeletal superstructure of the erythrocyte plasma membrane.']
# ...
